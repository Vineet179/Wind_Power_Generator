# %%
import pandas as pd

try:
    df = pd.read_csv('/content/Untitled Folder/Location3.csv')
    display(df.head())
except FileNotFoundError:
    print("Error: 'Location3.csv' not found. Please ensure the file exists in the current directory or provide the correct path.")
    df = None
except pd.errors.ParserError:
    print("Error: Could not parse the CSV file. Please check the file format.")
    df = None
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    df = None
# Out:
#                   Time  temperature_2m  relativehumidity_2m  dewpoint_2m  \
# 0  2017-01-02 00:00:00            29.7                   55         15.4
# 1  2017-01-02 01:00:00            29.6                   56         15.6
# 2  2017-01-02 02:00:00            29.8                   56         16.1
# 3  2017-01-02 03:00:00            29.8                   58         16.8
# 4  2017-01-02 04:00:00            30.2                   59         17.8
#
#    windspeed_10m  windspeed_100m  winddirection_10m  winddirection_100m  \
# 0           4.96            8.46                124                 129
# 1           4.97            8.43                120                 124
# 2           5.69            9.18                121                 123
# 3           5.49            8.88                123                 126
# 4           5.19            8.36                124                 127
#
#    windgusts_10m   Power
# 0            8.8  0.3438
# 1            8.5  0.3954
# ...

# %%
# Data Shape and Types
print("Data Shape:", df.shape)
print("\nData Types:\n", df.dtypes)

# Missing Values
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100
print("\nMissing Values:\n", missing_values)
print("\nMissing Value Percentage:\n", missing_percentage)

# Descriptive Statistics
print("\nDescriptive Statistics:\n", df.describe())

# Unique Values (Categorical Columns)
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\nUnique values for {col}:\n{df[col].value_counts()}")

# Correlation Analysis (Numerical Columns)
numerical_cols = df.select_dtypes(include=['number']).columns
correlation_matrix = df[numerical_cols].corr()
print("\nCorrelation Matrix:\n", correlation_matrix)
# Out:
# Data Shape: (43800, 10)
#
# Data Types:
#  Time                    object
# temperature_2m         float64
# relativehumidity_2m      int64
# dewpoint_2m            float64
# windspeed_10m          float64
# windspeed_100m         float64
# winddirection_10m        int64
# winddirection_100m       int64
# windgusts_10m          float64
# Power                  float64
# dtype: object
#
# Missing Values:
#  Time                   0
# temperature_2m         0
# relativehumidity_2m    0
# dewpoint_2m            0
# windspeed_10m          0
# windspeed_100m         0
# winddirection_10m      0
# winddirection_100m     0
# windgusts_10m          0
# Power                  0
# dtype: int64
#
# Missing Value Percentage:
#  Time                   0.0
# temperature_2m         0.0
# relativehumidity_2m    0.0
# dewpoint_2m            0.0
# windspeed_10m          0.0
# windspeed_100m         0.0
# winddirection_10m      0.0
# winddirection_100m     0.0
# windgusts_10m          0.0
# ...

# %%
# Data Shape and Types
print("Data Shape:", df.shape)
print("\nData Types:\n", df.dtypes)

# Missing Values
missing_values = df.isnull().sum()
missing_percentage = (missing_values / len(df)) * 100
print("\nMissing Values:\n", missing_values)
print("\nMissing Value Percentage:\n", missing_percentage)

# Descriptive Statistics
print("\nDescriptive Statistics:\n", df.describe())

# Unique Values (Categorical Columns)
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\nUnique values for {col}:\n{df[col].value_counts()}")

# Correlation Analysis (Numerical Columns)
numerical_cols = df.select_dtypes(include=['number']).columns
correlation_matrix = df[numerical_cols].corr()
print("\nCorrelation Matrix:\n", correlation_matrix)
# Out:
# Data Shape: (43800, 11)
#
# Data Types:
#  Time                   datetime64[ns]
# temperature_2m                float64
# relativehumidity_2m             int64
# dewpoint_2m                   float64
# windspeed_10m                 float64
# windspeed_100m                float64
# winddirection_10m               int64
# winddirection_100m              int64
# windgusts_10m                 float64
# Power                         float64
# Hour                            int32
# dtype: object
#
# Missing Values:
#  Time                   0
# temperature_2m         0
# relativehumidity_2m    0
# dewpoint_2m            0
# windspeed_10m          0
# windspeed_100m         0
# winddirection_10m      0
# winddirection_100m     0
# windgusts_10m          0
# Power                  0
# Hour                   0
# dtype: int64
#
# Missing Value Percentage:
#  Time                   0.0
# temperature_2m         0.0
# relativehumidity_2m    0.0
# dewpoint_2m            0.0
# ...

# %%
import matplotlib.pyplot as plt

# Numerical features
numerical_cols = ['temperature_2m', 'relativehumidity_2m', 'dewpoint_2m', 'windspeed_10m', 'windspeed_100m', 'winddirection_10m', 'winddirection_100m', 'windgusts_10m', 'Power']
for col in numerical_cols:
    plt.figure(figsize=(8, 6))  # Adjust figure size as needed
    plt.hist(df[col], bins=30, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.savefig(f'{col}_histogram.png')
    plt.close()

# Categorical feature: Time
plt.figure(figsize=(12, 6))
time_counts = df['Time'].value_counts().sort_values(ascending=False)
plt.bar(time_counts.index, time_counts.values, color='lightcoral')
plt.title('Frequency of Time Values')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.savefig('Time_bar_chart.png')
plt.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-53e1fb39b62a> in <cell line: 0>()
#      15 plt.figure(figsize=(12, 6))
#      16 time_counts = df['Time'].value_counts().sort_values(ascending=False)
# ---> 17 plt.bar(time_counts.index, time_counts.values, color='lightcoral')
#      18 plt.title('Frequency of Time Values')
#      19 plt.xlabel('Time')
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Numerical Features Analysis
numerical_cols = ['temperature_2m', 'relativehumidity_2m', 'dewpoint_2m', 'windspeed_10m', 'windspeed_100m', 'winddirection_10m', 'winddirection_100m', 'windgusts_10m', 'Power']
print("Descriptive Statistics for Numerical Features:\n", df[numerical_cols].describe())

plt.figure(figsize=(12, 8))
df[numerical_cols].plot(kind='box', subplots=True, layout=(3, 3), sharex=False, sharey=False)
plt.tight_layout()
plt.show()

correlation_matrix = df[numerical_cols].corr()
print("\nCorrelation Matrix for Numerical Features:\n", correlation_matrix)

# Categorical Feature Analysis
print("\nFrequency Distribution of Time Values:\n", df['Time'].value_counts())
try:
    df['Time'] = pd.to_datetime(df['Time'])
    print("\nSuccessfully converted 'Time' column to datetime format.")
except ValueError as e:
    print(f"\nError converting 'Time' to datetime: {e}")

# Relationship between Numerical and Categorical Features
df['Hour'] = df['Time'].dt.hour
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    df.groupby('Hour')[col].mean().plot()
    plt.title(f'Average {col} by Hour')
    plt.xlabel('Hour')
    plt.ylabel(f'Average {col}')
    plt.show()

# Summarize findings (printed to console)
print("\nSummary of Findings:")
print("1. Descriptive Statistics: Calculated mean, median, standard deviation, min, and max values for numerical features. Box plots were created to show distribution and potential outliers.")
print("2. Correlation Analysis: Analyzed the correlation between numerical features, and it was printed.")
print("3. Time Analysis: The frequency distribution of time values was analyzed, and an attempt to convert the 'Time' column to datetime format was made.")
print("4. Numerical vs. Time: The relationship between numerical features and the 'Time' column (hour) was explored by calculating and plotting the average of each numerical feature for each hour.")
# Out:
# Descriptive Statistics for Numerical Features:
#         temperature_2m  relativehumidity_2m   dewpoint_2m  windspeed_10m  \
# count    43800.000000         43800.000000  43800.000000   43800.000000
# mean        49.225632            68.290708     38.225450       4.334103
# std         22.551070            17.865965     21.901316       2.061304
# min        -26.700000            12.000000    -35.500000       0.000000
# 25%         32.000000            55.000000     22.800000       2.730000
# 50%         50.300000            70.000000     38.100000       4.050000
# 75%         68.400000            83.000000     57.900000       5.600000
# max        101.700000           100.000000     78.700000      18.530000
#
#        windspeed_100m  winddirection_10m  winddirection_100m  windgusts_10m  \
# count    43800.000000       43800.000000        43800.000000   43800.000000
# mean         7.047603         194.807100          194.897055       8.134600
# ...
